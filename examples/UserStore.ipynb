# %%
# %load_ext dotenv
# %dotenv
import os

SN_API_HOST = os.getenv('SN_API_HOST')
SN_API_KEY = os.getenv('SN_API_KEY')

# %%
from signals_notebook.api import SignalsNotebookApi
SignalsNotebookApi.init(SN_API_HOST, SN_API_KEY)

# %%
from signals_notebook.users.user_store import UserStore

user = UserStore.get('147')
user
# Out:
# User(is_enabled=False, id='147', username='unique3@quantori.com', email='unique3@quantori.com', alias='alias2', first_name='first_name', last_name='last_name', country='USA', organization='orga', created_at=datetime.datetime(2022, 7, 7, 11, 49, 14, 627000, tzinfo=datetime.timezone.utc), last_login_at=None)

# %%
user.roles
# Out:
# [Role(id='1', name='System Admin', description='Users with this role have all privileges.', privileges=Privelege(can_move_experiments=True, can_manage_system_templates=True, can_trash_requests=True, can_trash_samples=True, can_share=True, can_add_materials=True, can_trash_experiments=True, can_trash_materials=True, can_trash_notebooks=True, can_view_materials=True, can_manage_material_libraries=True, can_share_templates=True, can_manage_attributes=True, can_manage_groups=True, can_search_eln_archive=True, can_configure=True, can_edit_materials=True)),
#  Role(id='3', name='Standard User', description='All users in the system will always have this role.', privileges=Privelege(can_move_experiments=True, can_manage_system_templates=True, can_trash_requests=True, can_trash_samples=True, can_share=True, can_add_materials=True, can_trash_experiments=True, can_trash_materials=True, can_trash_notebooks=True, can_view_materials=True, can_manage_material_libraries=True, can_share_templates=True, can_manage_attributes=True, can_manage_groups=True, can_search_eln_archive=True, can_configure=True, can_edit_materials=True))]

# %%
user.groups
# Out:
# [Group(type=<ObjectType.GROUP: 'group'>, id='101', is_system=True, name='Administrators', description='Group containing all administrators', created_at=datetime.datetime(2021, 10, 22, 13, 35, 58, 444000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2021, 10, 22, 13, 35, 58, 444000, tzinfo=datetime.timezone.utc), digest='43037369'),
#  Group(type=<ObjectType.GROUP: 'group'>, id='102', is_system=True, name='All users', description='Group containing all users', created_at=datetime.datetime(2021, 10, 22, 13, 35, 58, 625000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2021, 10, 22, 13, 35, 58, 625000, tzinfo=datetime.timezone.utc), digest='99368757')]

# %%
current_user_profile = UserStore.get_current_user()
current_user = UserStore.get(current_user_profile.id)
current_user
# Out:
# User(is_enabled=True, id='103', username='sergey.kuznetsov@quantori.com', email='sergey.kuznetsov@quantori.com', alias=None, first_name='Sergey', last_name='Kuznetsov', country='USA', organization='quantori', created_at=datetime.datetime(2021, 11, 3, 3, 0, 6, 567000, tzinfo=datetime.timezone.utc), last_login_at=datetime.datetime(2022, 7, 12, 9, 6, 13, 836000, tzinfo=datetime.timezone.utc), _relationships=None)

# %%
from signals_notebook.common_types import File

file = current_user.picture
assert isinstance(file, File)
file
# Out:
# File(name='Sergey_Kuznetsov.jpg', content=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x02\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\xff\xdb\x00C\x01\t\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222\xff\xc0\x00\x11\x08\x03\x01\x02\xf5\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\xff\xc4\x00\xb5\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n\x16$4\xe1%\xf1\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz?\x00\xe9\xa8\xa2\x8a\xf4O0(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x9a]GR(\xb8\xec\xd8\xea*#<c\xf8\x85G%\xecH>\xf6j\x1c\xe2\xba\x94\xa9\xc9\xf4,\xd1Y\xc6\xf9\xa48\x8cU&\xd5%i\xfc\xa5\x04\xfb\x81\x91Y<L\x11\xbcp\xb5\x19\xbd\x9a+%n&\x0c\xa1\xb3\x93Vf\xbe\xb5\x81@7*_\xfb\xa3\'\x15?Z\x81_S\x99v\x8a\xcf\x8e\xef\xcd#cg5o\xf7\x8a\x9b\x98\x10=\xc55\x8a\x8b\x07\x83\x9a%\xa2\xa3\xdcv\x86\'\xa9\xc7\xe3R\xa4R\x92\xdf\xbbq\xb7\xaeV\x9a\xc4E\x92\xf0\xb3BQH\x18\x13\x8c\xd2\xd6\xe9\xa7\xaa9\x9ai\xd9\x85\x14QLAE\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x0 ...

# %%
user.first_name = 'NEW'
user
# Out:
# User(is_enabled=False, id='147', username='unique3@quantori.com', email='unique3@quantori.com', alias='alias2', first_name='NEW', last_name='last_name', country='USA', organization='orga', created_at=datetime.datetime(2022, 7, 7, 11, 49, 14, 627000, tzinfo=datetime.timezone.utc), last_login_at=None)

# %%
user.refresh()
user
# Out:
# User(is_enabled=False, id='147', username='unique3@quantori.com', email='unique3@quantori.com', alias='alias2', first_name='first_name', last_name='last_name', country='USA', organization='orga', created_at=datetime.datetime(2022, 7, 7, 11, 49, 14, 627000, tzinfo=datetime.timezone.utc), last_login_at=None)

# %%
from signals_notebook.users.user import User

users = UserStore.get_list()
for item in users:
    assert isinstance(item, User)

# %%
user
# Out:
# User(is_enabled=False, id='147', username='unique3@quantori.com', email='unique3@quantori.com', alias='alias2', first_name='first_name', last_name='last_name', country='USA', organization='orga', created_at=datetime.datetime(2022, 7, 7, 11, 49, 14, 627000, tzinfo=datetime.timezone.utc), last_login_at=None)

# %%
from signals_notebook.users.profile import Role

role = Role.get('1')

new_user = User.create(alias='alias36',
    country='USA',
    email='unique36@quantori.com',
    first_name='first_name',
    last_name='last_name',
    organization='orga',
    roles=[role])

new_user
# Out:
# ---------------------------------------------------------------------------
# SignalsNotebookError                      Traceback (most recent call last)
# Input In [13], in <cell line: 5>()
#       1 from signals_notebook.users.profile import Role
#       3 role = Role.get('1')
# ----> 5 new_user = User.create(alias='alias36',
#       6     country='USA',
#       7     email='unique36@quantori.com',
#       8     first_name='first_name',
#       9     last_name='last_name',
#      10     organization='orga',
#      11     roles=[role])
#      13 new_user
#
# File ~\PycharmProjects\pesn-python-sdk\src\signals_notebook\users\user.py:66, in User.create(cls, alias, country, email, first_name, last_name, organization, roles)
#      64 api = SignalsNotebookApi.get_default_api()
#      65 log.debug('Create User: %s...', cls.__name__)
# ---> 66 response = api.call(
#      67     method='POST',
#      68     path=(cls._get_endpoint(),),
#      69     json={
#      70         'data': {
#      71             'attributes': {
#      72                 'alias': alias,
#      73                 'country': country,
#      74                 'emailAddress': email,
#      75                 'firstName': first_name,
#      76                 'lastName': last_name,
#      77                 'organization': organization,
#      78                 'roles': [role.dict(include={'id', 'name'}) for role in roles] if roles else None,
#      79             },
#      80         }
#      81     },
#      82 )
#      83 log.debug('User: %s was created.', cls.__name__)
#      85 result = UserResponse(**response.json())
#
# File ~\PycharmProjects\pesn-python-sdk\src\signals_notebook\api.py:152, in SignalsNotebookApi.call(self, method, path, params, data, json, headers)
#     146 if not response.ok:
#     147     log.error(
#     148         'Error has been occurred while getting response, status code: %s',
#     149         response.status_code,
#     150         extra={'response': response},
#     151     )
# --> 152     raise SignalsNotebookError(response)
#     153 log.info('Successful request - HTTP url: %s, status code: %s', response.url, response.status_code)
#     155 return response
#
# SignalsNotebookError: <SignalsNotebookError status=409 code=Conflict> title= detail=Failed to create user (409): User <unique36@quantori.com> already exists.>

# %%
new_user.first_name = 'Test User'
new_user.save()

# %%
new_user.refresh()
new_user
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 new_user.refresh()
#       2 new_user
#
# NameError: name 'new_user' is not defined

# %%
new_user.delete()
