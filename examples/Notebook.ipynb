# %%
# %load_ext dotenv
# %dotenv
import os

SN_API_HOST = os.getenv('SN_API_HOST')
SN_API_KEY = os.getenv('SN_API_KEY')

# %%
from signals_notebook.api import SignalsNotebookApi

SignalsNotebookApi.init(SN_API_HOST, SN_API_KEY)

# %%
from signals_notebook.entities.notebook import Notebook

notebook = Notebook.create(
    name='Example notebook created by SDK examples',
    description='Delete if you see this in UI',
)

# %%
notebook.name = "Test save by SDK"
notebook.description = "Changed by me"
notebook.save()

# %%
notebook.delete()

# %%
from signals_notebook.entities import EntityStore

notebook = EntityStore.get("journal:c54da414-87d0-448f-8987-b3f58d819f1e")
list(notebook.get_children())
# Out:
# [Experiment(type=<EntityType.EXPERIMENT: 'experiment'>, eid='experiment:a16616ef-e1d5-4409-a9b6-c253c359d504', digest='26605711', name='Example', description='', created_at=datetime.datetime(2022, 8, 30, 8, 35, 3, 286000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 30, 8, 47, 54, 500000, tzinfo=datetime.timezone.utc), state=<ExperimentState.OPEN: 'open'>)]

# %%
from signals_notebook.common_types import EntityType

list(EntityStore.get_list(include_types=[EntityType.NOTEBOOK]))
# Out:
# [Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:cbabfd5e-b6d3-4a0b-b8ca-fb4abe40ff6f', digest='95590489', name='DEFAULT_NOTEBOOK', description='', created_at=datetime.datetime(2021, 10, 22, 13, 36, 1, 989000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2021, 11, 8, 8, 23, 19, 789000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:5736bb66-320b-418b-afd8-33799f623022', digest='39244831', name='My Notebook 1 (SK)', description='Description of notebook 1', created_at=datetime.datetime(2021, 11, 3, 10, 56, 40, 96000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2021, 11, 9, 13, 39, 52, 451000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:81742b56-963c-451a-85f7-1819ff4abef7', digest='38821397', name='My Notebook 2 (SK)', description='', created_at=datetime.datetime(2021, 11, 3, 10, 59, 47, 949000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2021, 11, 9, 13, 37, 13, 410000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:c3c9774c-8634-48fa-be40-991bbf617741', digest='48894246', name='My Notebook 3 (SK)', description='', created_at=datetime.datetime(2021, 11, 3, 11, 20, 32, 405000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2021, 11, 9, 13, 37, 38, 792000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:41e64f1c-595c-4b58-bd0d-c22c192e520f', digest='93994397', name='My Notebook 4 with Custom Object (SK)', description='', created_at=datetime.datetime(2021, 11, 8, 7, 35, 47, 69000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2021, 11, 9, 13, 36, 51, 230000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:23515a28-16cc-45a0-a241-e0eb7c806531', digest='65975512', name='My Notebook 5 (SK)', description='', created_at=datetime.datetime(2021, 11, 8, 8, 25, 36, 397000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2021, 11, 23, 15, 14, 2, 556000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:e2df7e46-53a2-435b-bbfd-704beeb2e956', digest='52696933', name='Book-SL-1', description='', created_at=datetime.datetime(2021, 11, 12, 6, 13, 6, 594000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2021, 11, 12, 6, 13, 6, 594000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:d7f9b227-7c55-46ec-8476-dad41250126f', digest='18056131', name='Alprostadil', description='The notebook is purposed to model the laboratory workflow of obtainment and analysis of Alprostadil.', created_at=datetime.datetime(2021, 11, 18, 7, 56, 47, 565000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2021, 11, 18, 7, 56, 47, 565000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:64014286-7d05-4630-9556-0e5db62d0550', digest='94852597', name='Insulin', description='The notebook is purposed to model the laboratory workflow of biosynthesis and analysis of recombinant Insulin.', created_at=datetime.datetime(2021, 11, 30, 13, 34, 4, 55000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2021, 11, 30, 13, 34, 4, 55000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:8618c2b5-bc0b-4fee-a972-e45827d8c6ee', digest='83301414', name='Peptide Synthesis', description='approaches to peptide synthesis', created_at=datetime.datetime(2021, 12, 3, 9, 46, 43, 67000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2021, 12, 3, 9, 46, 43, 67000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:107105ef-4479-431f-9f75-7143a550c650', digest='46680482', name='journal-example-01', description='', created_at=datetime.datetime(2022, 5, 16, 8, 31, 3, 997000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 5, 16, 8, 31, 3, 997000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:8ebf5e9b-b2b7-4945-84d1-b10fc2c61318', digest='80456148', name='journal-example-02', description='', created_at=datetime.datetime(2022, 5, 18, 13, 22, 26, 289000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 5, 18, 13, 22, 26, 289000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:06798683-1010-498f-8f00-75fcd1a9ad7d', digest='87154622', name='journal-example22', description='', created_at=datetime.datetime(2022, 6, 29, 8, 12, 43, 325000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 6, 29, 8, 12, 43, 325000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:0178b553-7654-45b9-85e7-073408d9c479', digest='51089008', name='unique name', description='', created_at=datetime.datetime(2022, 6, 29, 10, 59, 19, 418000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 6, 29, 10, 59, 19, 418000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:e580b1b4-3f19-44c4-b76e-20ce11d14eab', digest='11308855', name='journal-example2', description='', created_at=datetime.datetime(2022, 6, 30, 11, 11, 55, 807000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 6, 30, 11, 11, 55, 807000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:887af802-b618-48c5-8d9c-bde013b69b52', digest='62233098', name='Test-exp-QA', description='', created_at=datetime.datetime(2022, 7, 1, 3, 26, 5, 473000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 7, 1, 3, 26, 5, 473000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:5662f12a-85f2-4284-bd3f-2d551efa8219', digest='49806957', name='Test-exp-QA1', description='', created_at=datetime.datetime(2022, 7, 1, 3, 41, 57, 588000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 7, 1, 3, 41, 57, 588000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:da8d7173-86dd-47ed-9ac1-46ac7f36254b', digest='71139986', name='restore:unique name', description='', created_at=datetime.datetime(2022, 7, 6, 13, 10, 56, 97000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 7, 6, 13, 10, 56, 97000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:90880722-4e46-4112-9107-5ca19cfc4b3e', digest='74511337', name='restore:journal-example22', description='', created_at=datetime.datetime(2022, 7, 6, 13, 10, 56, 934000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 7, 6, 13, 10, 56, 934000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:aeced906-32ea-4611-b9f1-144e9a9b8757', digest='19275650', name='restore:Revised_Insulin', description='Revision of the Insulin case', created_at=datetime.datetime(2022, 7, 6, 13, 10, 57, 815000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 7, 6, 13, 10, 57, 815000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:3fba849f-145e-4f91-b371-07ffeccb05cd', digest='27093677', name='restore:PrimerNET-1', description='', created_at=datetime.datetime(2022, 7, 6, 13, 10, 59, 467000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 7, 6, 13, 10, 59, 467000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:596b3c3d-fb50-43ec-a551-6a531b4b84a4', digest='11960225', name='restore:restore:Test creation by SDK', description='Created by Eugene Pokidov', created_at=datetime.datetime(2022, 7, 6, 13, 11, 1, 226000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 7, 6, 13, 11, 1, 226000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:ed4f00e2-71f4-4d95-b7f3-944fae8590ef', digest='97465497', name='restore:journal-example-01', description='', created_at=datetime.datetime(2022, 7, 6, 13, 11, 2, 542000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 7, 6, 13, 11, 2, 542000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:f71a1e2b-bd25-47d3-b030-1d27ec51948e', digest='46600951', name='restore:TSK-000001', description='', created_at=datetime.datetime(2022, 7, 6, 13, 11, 3, 297000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 7, 6, 13, 11, 3, 297000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:14b6a726-9cfc-4269-bf28-f0f40bbbeb3b', digest='75072287', name='restore:Test creation by SDK', description='Created by Eugene Pokidov', created_at=datetime.datetime(2022, 7, 6, 13, 11, 3, 935000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 7, 6, 13, 11, 3, 935000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:d23529c3-f177-4aaf-8575-5c766a1a2038', digest='80171797', name='restore:Test save by SDK', description='Changed by me', created_at=datetime.datetime(2022, 7, 6, 13, 11, 13, 358000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 7, 6, 13, 11, 13, 358000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:4deff948-163e-4e75-bbb2-b9f219eace5e', digest='77525103', name='Example notebook created by SDK', description='Delete if you see this in UI', created_at=datetime.datetime(2022, 7, 11, 9, 52, 5, 356000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 7, 11, 9, 52, 5, 356000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:66b4b4d7-b7e8-488d-bafa-71f4d678d486', digest='43024896', name='restore:Demonstration experiment', description='', created_at=datetime.datetime(2022, 7, 15, 12, 20, 18, 928000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 7, 15, 12, 20, 18, 928000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:e5fb6ddd-79b6-4452-998f-f5ec82bbf863', digest='22254860', name='restore:Contentful Entity Full', description='', created_at=datetime.datetime(2022, 7, 19, 21, 17, 31, 29000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 7, 19, 21, 17, 31, 29000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:106d9be5-8b46-4246-9d73-7f246e631456', digest='89354255', name='testrail case', description='', created_at=datetime.datetime(2022, 7, 20, 7, 47, 24, 154000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 7, 20, 7, 47, 24, 154000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:d153b64a-ea00-4402-966e-ff9001873177', digest='17575920', name='restore:AWS TABLES', description='', created_at=datetime.datetime(2022, 7, 26, 11, 55, 29, 191000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 7, 26, 11, 55, 29, 191000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:68a5e872-091d-4194-bb61-c0a8533879cf', digest='65639732', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 19, 11, 30, 3, 353000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 19, 11, 30, 3, 353000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:52f4238d-f119-4910-be16-524411dbbb5b', digest='19274385', name='Initial notebook', description='', created_at=datetime.datetime(2021, 11, 3, 13, 34, 35, 533000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2021, 11, 3, 13, 34, 35, 533000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:5b9d1d1e-5b51-40c5-9fa1-907aa6899af2', digest='19420221', name='Electrophoresis', description='Protocols of analysis for gel electrophoresis for monoclonal antibodies', created_at=datetime.datetime(2021, 11, 9, 14, 10, 24, 82000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2021, 11, 10, 11, 7, 0, 496000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:9ac7b7c5-9583-4089-948e-00a2f61847b6', digest='52707259', name='test notebook', description='description 1', created_at=datetime.datetime(2021, 11, 9, 20, 4, 28, 42000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2021, 11, 9, 20, 4, 28, 42000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:d2f6b7a7-7ba8-4463-aa83-d125256bedd2', digest='30648310', name='SPI', description='Sulfonated polyimides as perspective materials for the development of diffusion membranes', created_at=datetime.datetime(2021, 11, 10, 7, 12, 45, 741000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2021, 11, 10, 7, 12, 45, 741000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:6c9f69ac-ff4f-44a2-b1c5-1770f329c387', digest='22763523', name='AK_Test_NoteBook', description='Test Notebook', created_at=datetime.datetime(2021, 11, 10, 7, 44, 10, 772000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2021, 11, 10, 7, 44, 10, 772000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:e4f22a7f-961e-415c-a966-b6f5e91dd070', digest='66478609', name='TGA_ILs', description='', created_at=datetime.datetime(2021, 11, 10, 17, 15, 38, 595000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2021, 11, 10, 17, 15, 38, 595000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:eb3b4666-f772-4bb9-8383-6012dde4fe08', digest='91593159', name='AK-001_Notebook', description="Anatoliy's work book", created_at=datetime.datetime(2021, 11, 11, 10, 23, 10, 987000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2021, 11, 11, 10, 23, 10, 987000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:110a8af2-010b-491d-a8fa-6168c80d9910', digest='98451096', name='TSK-000001', description='', created_at=datetime.datetime(2021, 11, 11, 10, 53, 27, 938000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2021, 11, 11, 10, 53, 27, 938000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:3bdeff97-4dc4-438e-a5f3-e6131fd66281', digest='92266913', name='Laboratory1', description='analytical laboratory journal', created_at=datetime.datetime(2021, 11, 12, 7, 32, 59, 678000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2021, 11, 12, 7, 32, 59, 678000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:8adab7fc-9a4e-4180-8bf3-f0835dd4a938', digest='79045577', name='Alprostadil notebook', description='Full cycle of alrprostadil synthesys, QC, and phase 1 trial parts.', created_at=datetime.datetime(2021, 11, 21, 9, 51, 51, 955000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2021, 11, 21, 9, 51, 51, 955000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:97ddfe93-96dd-48cc-a50b-a40b47a3f131', digest='14260877', name='Alprostadil 2', description='Test 2', created_at=datetime.datetime(2021, 11, 22, 17, 5, 28, 269000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2021, 11, 22, 17, 5, 28, 269000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:81992115-5e21-4643-9187-9eb5a1dcf3db', digest='77298028', name='Biologic assays', description='Examples of biologic assays', created_at=datetime.datetime(2021, 11, 24, 10, 40, 10, 654000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2021, 11, 24, 10, 40, 10, 654000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:ca6dfc61-eaea-40ee-8810-505874a565a5', digest='56249659', name='Functions testing', description='Try to use different features separately', created_at=datetime.datetime(2021, 11, 25, 8, 20, 57, 721000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2021, 11, 25, 8, 20, 57, 721000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:daa080ee-50a2-496b-ba8f-8dacb3c38fbe', digest='13079140', name='Custom API Features', description='This notebook contains entities which demonstrate the possibilities of SIgnals enhancment through API added functionality', created_at=datetime.datetime(2021, 11, 26, 8, 32, 24, 523000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2021, 11, 26, 8, 32, 24, 523000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:92beda21-d1c7-4fa8-b99b-6ed5003c611c', digest='44514572', name='BPVA_01', description='', created_at=datetime.datetime(2022, 1, 14, 14, 23, 51, 174000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 1, 14, 14, 23, 51, 174000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:6c621c7b-8dc2-478d-9458-1e23bdd6ccbf', digest='69963091', name='Test_1', description='', created_at=datetime.datetime(2022, 1, 20, 9, 0, 55, 851000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 1, 20, 9, 0, 55, 851000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:26c23881-cf45-4402-8f19-01c328debc08', digest='21155561', name='OLED', description='', created_at=datetime.datetime(2022, 2, 2, 13, 49, 22, 424000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 2, 2, 13, 49, 22, 424000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:9fb3517d-12c4-4e08-ad77-d2f32f47ead4', digest='35545938', name='test34556', description='3456', created_at=datetime.datetime(2022, 2, 2, 14, 22, 47, 325000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 2, 2, 14, 22, 47, 325000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:95008b65-672b-425e-a525-b4abd1e7b7b5', digest='74537190', name='Brain rodents clinical research', description='', created_at=datetime.datetime(2022, 2, 2, 14, 47, 42, 499000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 2, 2, 14, 47, 42, 499000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:3b825137-c2c7-467a-b196-e57baab4b247', digest='64125703', name='qPCR', description='', created_at=datetime.datetime(2022, 2, 15, 11, 38, 46, 378000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 2, 15, 11, 38, 46, 378000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:80fee219-7d50-4abd-8698-22175eb980d4', digest='33129414', name='OLED workflow', description='', created_at=datetime.datetime(2022, 2, 15, 12, 19, 57, 934000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 2, 15, 12, 19, 57, 934000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:20f305a1-e73b-4f4b-9b43-48569a837d91', digest='15344620', name='Hansen solubility Parameters', description='The Experiment describes a procedure for the determination of a Hansen solubility parameters set for a given polymer', created_at=datetime.datetime(2022, 2, 21, 7, 7, 31, 390000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 2, 21, 7, 7, 31, 390000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:37928338-cf49-4786-a69f-fda0a05c8d27', digest='66719520', name='Animal research', description='Demo', created_at=datetime.datetime(2022, 2, 21, 9, 54, 17, 382000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 3, 9, 9, 33, 27, 932000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:9429bd81-da81-46af-b180-e0a8694b1f95', digest='86440261', name='Open Experiments', description='', created_at=datetime.datetime(2022, 2, 23, 16, 34, 11, 232000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 2, 23, 16, 34, 11, 232000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:f2649a74-faba-4566-b62b-bef58a0f88e6', digest='23628373', name='Smoke check list Signals', description='Smoke check list Signals according to Alprostadil and Insulin flow of experiment', created_at=datetime.datetime(2022, 2, 25, 3, 44, 36, 114000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 2, 25, 3, 44, 36, 114000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:1a2e876f-14ee-4f78-bd7f-ed769c117c4d', digest='37512485', name='Speech transcript', description='', created_at=datetime.datetime(2022, 3, 16, 9, 9, 47, 203000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 3, 16, 9, 9, 47, 203000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:07cfb2bf-420a-490a-a2df-b2ca6bc8b8c7', digest='58823484', name='Revised_Insulin', description='Revision of the Insulin case', created_at=datetime.datetime(2022, 3, 17, 11, 22, 46, 399000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 3, 17, 11, 22, 46, 399000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:8b48da9c-6173-4b08-8b07-1d35edea06ef', digest='23274544', name='Ol', description='Determination platinum content', created_at=datetime.datetime(2022, 4, 18, 6, 58, 53, 435000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 4, 18, 6, 58, 53, 435000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:ad8ac8ab-7bd2-4efc-a7fc-0e8871069242', digest='66495326', name='1', description='123', created_at=datetime.datetime(2022, 4, 20, 5, 40, 29, 60000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 4, 20, 5, 40, 29, 60000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:7e4f0c41-1458-4b68-8830-34178fe7c151', digest='50989237', name='PrimetTest', description='', created_at=datetime.datetime(2022, 5, 5, 16, 10, 29, 324000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 5, 5, 16, 10, 29, 324000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:0a8fc59f-653d-48b0-96d8-bef47e95ce2d', digest='98252257', name='PrimerNET-1', description='', created_at=datetime.datetime(2022, 5, 11, 10, 47, 51, 716000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 5, 11, 10, 47, 51, 716000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:44c5a1a1-e181-4df1-ba34-ca078508d457', digest='61907977', name='TestNotebook', description='', created_at=datetime.datetime(2022, 5, 16, 6, 58, 20, 547000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 5, 16, 6, 58, 20, 547000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:e21317c4-70db-4722-b193-b7bbae4ec2c5', digest='30891396', name='journal-example', description='', created_at=datetime.datetime(2022, 5, 16, 8, 22, 49, 320000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 5, 16, 8, 22, 49, 320000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:89dc15c0-2e67-4616-b21d-166384dad377', digest='50237847', name='Messenger Integration', description='A test notebook for messenger integration', created_at=datetime.datetime(2022, 5, 23, 9, 5, 13, 338000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 5, 23, 9, 5, 13, 338000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:7bf9562a-e67a-4cb5-90e5-61c1512ef47b', digest='61927367', name='journal-example_01', description='', created_at=datetime.datetime(2022, 6, 1, 3, 41, 53, 367000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 6, 1, 3, 41, 53, 367000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:37099516-3b68-4f9d-acf9-79ab31cd7742', digest='52018540', name='journal-example-03', description='', created_at=datetime.datetime(2022, 6, 4, 6, 1, 40, 919000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 6, 4, 6, 1, 40, 919000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:a22226d6-30a4-4e8c-aaff-64ec1f3145e5', digest='38012918', name='Andrey sandbox', description='', created_at=datetime.datetime(2022, 6, 22, 15, 2, 19, 629000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 6, 22, 15, 2, 19, 629000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:dfb87eaa-d4aa-4a94-b515-84417dc6fdb8', digest='48573787', name='Testqa', description='', created_at=datetime.datetime(2022, 6, 28, 12, 3, 24, 297000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 6, 28, 12, 3, 24, 297000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:12d0555c-84a0-42fc-90d5-66f65070fd38', digest='66984335', name='Test-ag', description='Desc', created_at=datetime.datetime(2022, 7, 14, 21, 45, 2, 625000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 7, 14, 21, 45, 2, 625000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:21e4a882-5be1-4bf1-852f-25dda422e1f9', digest='88540089', name='Demonstration Notebook', description='', created_at=datetime.datetime(2022, 7, 15, 8, 58, 54, 681000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 7, 15, 8, 58, 54, 681000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:7b8b2f96-a7cb-4287-88ed-8f6df6e85ced', digest='49574825', name='Contentful Entity Full', description='', created_at=datetime.datetime(2022, 7, 18, 10, 28, 3, 337000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 7, 18, 10, 28, 3, 337000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:151542f5-dcc2-4dc7-bfc3-c5f0d204ea4c', digest='50919715', name='AWS TABLES', description='', created_at=datetime.datetime(2022, 7, 25, 11, 14, 1, 103000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 7, 25, 11, 14, 1, 103000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:9801ad65-9869-404f-80e8-5139a8d9ce03', digest='95553963', name='SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 1, 11, 24, 29, 360000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 1, 11, 24, 29, 360000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:c2648dec-42ef-4f05-ae31-ac897fe39d54', digest='54726517', name='QA Notebook by api', description='', created_at=datetime.datetime(2022, 8, 2, 14, 25, 29, 694000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 2, 14, 25, 31, 772000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:b2657e18-ad83-4e88-a62b-841a20467b77', digest='59209664', name='QA Notebook by SDK', description='description', created_at=datetime.datetime(2022, 8, 2, 14, 58, 51, 758000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 2, 14, 58, 53, 456000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:f306ff04-760b-4f2b-ba13-61e6045e156e', digest='79228222', name='QA Notebook by api', description='', created_at=datetime.datetime(2022, 8, 2, 14, 58, 54, 695000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 2, 14, 58, 56, 335000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:0f255eb0-4b53-4319-9de6-b5eb019fbc8a', digest='76069450', name='QA Notebook by api', description='', created_at=datetime.datetime(2022, 8, 2, 15, 4, 52, 85000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 2, 15, 4, 54, 167000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:86c9d86c-d209-4488-b93b-6791595f69d5', digest='58008906', name='QA Notebook by SDK', description='description', created_at=datetime.datetime(2022, 8, 2, 15, 4, 57, 494000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 2, 15, 4, 59, 250000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:183b2e9d-dce0-4a74-81cf-1ca80a1a6541', digest='20340723', name='QA Notebook by api', description='', created_at=datetime.datetime(2022, 8, 2, 15, 5, 0, 419000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 2, 15, 5, 2, 19000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:faaf2034-54f6-47c3-979c-5f8d90fd1bd1', digest='16479641', name='Test update by SDK', description='Changed by SDK', created_at=datetime.datetime(2022, 8, 2, 15, 5, 15, 570000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 2, 15, 5, 18, 271000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:2a5c7f90-fc4b-4252-b104-5537c78f4f42', digest='31818190', name='QA Notebook by api', description='', created_at=datetime.datetime(2022, 8, 2, 15, 9, 32, 980000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 2, 15, 9, 37, 319000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:32512a92-6a84-4ed8-b4e6-60f9b01c0ca5', digest='24813251', name='ваыфва', description='', created_at=datetime.datetime(2022, 8, 4, 13, 36, 0, 970000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 4, 13, 36, 0, 970000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:d5d9d96a-4e36-459c-b669-89666f4a3a75', digest='55960689', name='QA Notebook by api', description='', created_at=datetime.datetime(2022, 8, 10, 12, 9, 44, 360000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 10, 12, 9, 46, 446000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:a54b8794-769d-4ff9-9b6d-9d09713d25e1', digest='87291687', name='QA Notebook by SDK', description='description', created_at=datetime.datetime(2022, 8, 10, 12, 9, 49, 662000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 10, 12, 9, 51, 209000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:6da1b45b-8235-4566-afec-541458393a44', digest='12542657', name='QA Notebook by api', description='', created_at=datetime.datetime(2022, 8, 10, 12, 9, 52, 625000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 10, 12, 9, 54, 343000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:b5e04a7a-09e5-40c2-b6f6-e8fac4b979c9', digest='91612075', name='Test update by SDK', description='Changed by SDK', created_at=datetime.datetime(2022, 8, 10, 12, 10, 8, 345000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 10, 12, 10, 11, 656000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:8789e719-e1f1-4f9c-8ea1-f1a88e38e2f6', digest='83115651', name='QA Notebook by api', description='', created_at=datetime.datetime(2022, 8, 10, 13, 56, 34, 134000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 10, 13, 56, 36, 310000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:90cf85a3-5125-4f97-9bb9-90cc09a29d50', digest='69381368', name='QA Notebook by SDK', description='description', created_at=datetime.datetime(2022, 8, 10, 13, 56, 40, 50000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 10, 13, 56, 41, 883000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:636e7728-1665-4ce3-b052-72443af2b63d', digest='90460421', name='QA Notebook by api', description='', created_at=datetime.datetime(2022, 8, 10, 13, 56, 43, 265000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 10, 13, 56, 45, 545000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:b1876366-db47-4c3d-9f6a-e645fdf061f1', digest='89456888', name='Test update by SDK', description='Changed by SDK', created_at=datetime.datetime(2022, 8, 10, 13, 57, 1, 332000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 10, 13, 57, 4, 621000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:59874e43-65cb-4e99-870c-468b2776cdae', digest='88797739', name='SHISHKIN restore', description='', created_at=datetime.datetime(2022, 8, 15, 14, 21, 26, 197000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 15, 15, 10, 50, 527000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:2421d461-f059-4b03-b819-bd90c0c4683e', digest='39102093', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 15, 14, 44, 37, 812000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 15, 15, 13, 14, 353000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:3856da54-98c8-4960-8753-499c0555c1be', digest='87250272', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 15, 15, 15, 29, 660000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 15, 15, 16, 38, 815000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:57b0b6a5-7738-49d5-9294-f5133543d5f4', digest='19184009', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 15, 15, 16, 49, 702000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 15, 15, 21, 6, 991000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:fa8c8ea8-a189-4490-bfb6-b62c879059ac', digest='21738370', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 15, 15, 21, 15, 292000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 15, 15, 26, 20, 465000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:b4c6d902-6428-49fc-b4b4-32475dc6a170', digest='80078399', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 15, 15, 26, 29, 587000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 15, 15, 27, 23, 350000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:b31b58bb-f576-47c2-8941-9825eb29d857', digest='57730185', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 15, 15, 27, 31, 775000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 15, 15, 29, 32, 411000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:4fc41992-5396-4365-8615-b5db0dfe1460', digest='67764179', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 15, 15, 29, 41, 455000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 16, 10, 47, 43, 643000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:f1ef7c83-019c-4a79-a3ad-0a184c0701d1', digest='80699296', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 16, 10, 47, 51, 421000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 16, 10, 50, 44, 217000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:a908ef97-d4de-403e-92c8-a024926396cc', digest='45816756', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 16, 10, 51, 27, 380000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 16, 10, 52, 8, 581000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:455c1b6e-f63e-4702-ac14-0e44fb262e50', digest='58397987', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 16, 10, 54, 39, 328000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 16, 10, 59, 13, 359000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:1766ec9c-739d-4d67-9424-8f332cc06f62', digest='79392649', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 16, 10, 59, 22, 755000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 16, 11, 1, 57, 143000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:3371fa7e-33a3-475c-8336-8bec8748adf4', digest='45997812', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 16, 11, 2, 4, 542000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 16, 11, 6, 35, 555000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:7ee584b1-6650-4e8f-953d-0a358a9bc7f4', digest='34097614', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 16, 11, 6, 43, 436000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 16, 11, 17, 22, 785000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:7b1e5992-df20-4183-9053-5d10a1cbb267', digest='93555448', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 16, 11, 17, 33, 949000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 16, 11, 18, 14, 55000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:8a71901d-0585-4f33-b79d-e705dc497a8d', digest='29171551', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 16, 11, 18, 23, 66000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 16, 13, 44, 5, 34000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:b810859e-7050-4dd5-9769-bd4890607c8e', digest='36001354', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 16, 13, 47, 53, 913000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 16, 13, 53, 13, 580000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:e8f7a942-dfee-4ac5-ae97-7ce093b7e879', digest='90291228', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 16, 13, 53, 21, 454000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 16, 14, 2, 59, 109000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:99999222-6797-42d6-a330-7d6aa270d7b1', digest='19633687', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 16, 14, 3, 21, 796000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 16, 14, 4, 54, 687000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:8f2139f0-c7c4-4f1a-8af5-bef1ee723be1', digest='20824387', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 16, 14, 5, 7, 951000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 16, 14, 6, 11, 657000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:f9c0632b-c572-4ce2-baa2-e5dc009bfac2', digest='37953972', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 16, 14, 6, 19, 646000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 16, 14, 9, 15, 721000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:d4aa2cda-bfad-42a4-8911-0384c903fa1b', digest='49213516', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 16, 14, 9, 23, 897000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 16, 14, 13, 51, 459000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:c2a4c1d5-efbd-4342-9824-fbd900a15c9b', digest='71923375', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 16, 14, 15, 6, 836000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 16, 14, 21, 51, 425000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:d0a3e770-dcb4-48be-bcf0-717bcfd9dbab', digest='63189747', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 16, 14, 26, 11, 611000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 17, 6, 42, 40, 812000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:3fc03929-a3ba-4233-b83e-f36d278541d9', digest='43123409', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 17, 6, 43, 47, 963000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 17, 6, 51, 39, 369000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:8689e346-f89f-4aa7-a896-8f20c288f3ab', digest='71175154', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 17, 6, 51, 47, 618000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 17, 7, 22, 49, 274000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:66524c34-1658-43bd-9262-880bcf59a69a', digest='69446211', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 17, 7, 22, 58, 38000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 17, 8, 4, 40, 447000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:d8244656-49f7-49eb-afb6-635abdbe690c', digest='23528949', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 17, 8, 4, 49, 585000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 17, 8, 20, 43, 513000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:aa6795a9-a4fe-4f8a-ad27-3a7f0098800b', digest='69652567', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 17, 8, 21, 4, 160000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 17, 9, 8, 26, 561000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:c5dbac4b-0b3d-4b4d-9f93-6bb56256870a', digest='45285449', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 17, 9, 15, 34, 840000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 17, 12, 48, 57, 342000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:3e4ac9d3-a736-46fe-ae47-10cb57fd5d21', digest='15842426', name='QA Notebook by api', description='', created_at=datetime.datetime(2022, 8, 17, 11, 15, 55, 339000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 17, 11, 15, 57, 346000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:59b4681f-af74-452c-ad07-17b398ce9e3c', digest='27198781', name='QA Notebook by SDK', description='description', created_at=datetime.datetime(2022, 8, 17, 11, 16, 0, 250000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 17, 11, 16, 1, 919000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:836623c0-608d-46a0-90f8-7e59efcb3443', digest='57840378', name='QA Notebook by api', description='', created_at=datetime.datetime(2022, 8, 17, 11, 16, 3, 25000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 17, 11, 16, 4, 850000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:f334fcba-be2d-4625-b036-dce6bc6c7990', digest='15463293', name='Test update by SDK', description='Changed by SDK', created_at=datetime.datetime(2022, 8, 17, 11, 16, 18, 508000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 17, 11, 16, 21, 467000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:8622e29f-a403-45a2-91ce-955a872fd6f4', digest='53462087', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 17, 12, 49, 14, 491000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 17, 14, 40, 56, 443000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:1fff72bf-676b-4f98-8d82-d9999c06e8bc', digest='62299473', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 17, 14, 41, 3, 324000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 17, 14, 41, 53, 963000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:b838d6ac-063b-412d-870e-e21b39c5e342', digest='32620168', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 17, 14, 42, 3, 473000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 17, 14, 47, 11, 388000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:06e24ef0-4263-4eb6-b4dc-f5ab7f676b01', digest='67406510', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 17, 14, 48, 5, 512000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 17, 14, 56, 27, 265000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:d083df8d-a344-435c-a262-cea6f8376dc6', digest='47849109', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 17, 14, 56, 34, 721000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 17, 15, 4, 22, 697000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:e92b46d1-a292-4d4b-9297-055333d96986', digest='87579130', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 17, 15, 17, 20, 76000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 17, 15, 22, 10, 92000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:77e95d90-ce17-40fb-8cb4-508b58f237bd', digest='62980508', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 17, 15, 22, 19, 725000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 17, 15, 25, 55, 53000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:fbe91381-378b-4b5a-994c-f65bf5849e5e', digest='93192176', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 17, 15, 26, 2, 956000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 17, 15, 27, 5, 597000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:893ee55e-c4f5-4e47-838d-159443ff0f68', digest='89343522', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 17, 15, 27, 12, 610000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 17, 15, 29, 17, 84000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:51ef1159-bfcc-4536-9a01-7571574329bc', digest='58341208', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 17, 15, 29, 28, 71000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 17, 15, 32, 53, 63000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:c7007c36-9789-49d9-8ed9-5f0bc120d960', digest='61998914', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 17, 15, 33, 0, 340000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 17, 15, 36, 19, 147000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:63d41a7b-19a7-414d-8ecb-2ce3fd40b3d3', digest='67713359', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 17, 15, 36, 25, 881000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 17, 15, 41, 26, 945000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:e2f172b2-8816-4b0b-ba5e-099b4b8228f1', digest='81437392', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 17, 15, 41, 57, 413000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 17, 15, 44, 13, 325000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:6ae85b17-4aa4-42d9-bb47-ab171790d013', digest='83853461', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 17, 15, 44, 24, 311000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 17, 15, 49, 24, 620000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:38b911ca-f90f-4757-aaca-df07eeef3b3f', digest='85128291', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 17, 15, 49, 31, 859000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 17, 15, 49, 46, 858000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:f3fe0faa-7348-4614-85c7-a6a1d8c19911', digest='55377015', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 17, 15, 49, 58, 729000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 17, 15, 51, 50, 33000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:1ac34ff4-c0ed-48fa-b1e9-eb99b8782ab7', digest='33221956', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 17, 15, 51, 57, 77000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 17, 15, 55, 59, 889000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:97668928-d748-4017-b569-13de1b2044aa', digest='20314096', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 17, 15, 56, 6, 49000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 19, 11, 18, 9, 599000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:97ddd772-ee76-4b57-9ab2-eb1a18b242f0', digest='44354226', name='bls bls', description='', created_at=datetime.datetime(2022, 8, 18, 13, 22, 10, 202000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 18, 13, 22, 11, 24000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:7dfefa99-bd9b-435c-a64d-af5898d939cc', digest='31954918', name='bls bls', description='', created_at=datetime.datetime(2022, 8, 18, 13, 24, 49, 90000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 18, 13, 51, 7, 32000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:142fd555-3905-41b4-b0f4-60dba1d6c5a7', digest='14427680', name='bls bls', description='', created_at=datetime.datetime(2022, 8, 18, 13, 51, 20, 478000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 18, 13, 51, 58, 110000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:cb3309c0-144a-47a5-8eda-336dfd291206', digest='63119880', name='bls bls', description='', created_at=datetime.datetime(2022, 8, 18, 13, 52, 7, 433000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 18, 13, 52, 9, 193000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:6c47bc71-1a9d-4752-b8ba-79ddee76340e', digest='57186068', name='QA Notebook by api', description='', created_at=datetime.datetime(2022, 8, 18, 14, 10, 55, 425000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 18, 14, 10, 57, 539000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:27e37146-bf20-41c0-b4cf-aca09d0f4028', digest='89052262', name='QA Notebook by SDK', description='description', created_at=datetime.datetime(2022, 8, 18, 14, 10, 58, 893000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 18, 14, 11, 0, 915000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:f9ddf0ff-cb29-4345-b41d-f9630bb54aa5', digest='19869430', name='QA Notebook by api', description='', created_at=datetime.datetime(2022, 8, 18, 14, 11, 2, 122000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 18, 14, 11, 3, 753000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:e1e9a280-2cb2-4304-a669-cf96b196c89a', digest='16526721', name='Test update by SDK', description='Changed by SDK', created_at=datetime.datetime(2022, 8, 18, 14, 11, 17, 370000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 18, 14, 11, 20, 410000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:fd588578-611c-462f-b17d-fecfbb72e997', digest='15260125', name='QA Notebook by api', description='', created_at=datetime.datetime(2022, 8, 18, 14, 11, 21, 607000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 18, 14, 11, 24, 361000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:448cb559-e108-41c8-8c0f-fe519a51db41', digest='41636341', name='QA Notebook by api', description='', created_at=datetime.datetime(2022, 8, 18, 14, 12, 35, 489000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 18, 14, 12, 37, 717000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:5d260cbe-4139-4223-ba30-ed14bd37c99f', digest='82596491', name='QA Notebook by SDK', description='description', created_at=datetime.datetime(2022, 8, 18, 14, 12, 39, 186000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 18, 14, 12, 41, 5000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:e995ab36-1e0f-4296-967f-e2c1bb6e6606', digest='56014595', name='QA Notebook by api', description='', created_at=datetime.datetime(2022, 8, 18, 14, 12, 42, 383000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 18, 14, 12, 43, 989000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:1834f9cc-fa48-4a37-912a-71c56bb8802e', digest='24383933', name='Test update by SDK', description='Changed by SDK', created_at=datetime.datetime(2022, 8, 18, 14, 12, 57, 611000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 18, 14, 13, 0, 373000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:b8febc2e-8896-4bca-a2d9-df1b3a6bbbd7', digest='71349694', name='QA Notebook by api', description='', created_at=datetime.datetime(2022, 8, 18, 14, 13, 1, 620000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 18, 14, 13, 4, 52000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:4a931f91-f08d-47ea-b532-a35655a3fde4', digest='84924505', name='QA Notebook by api', description='', created_at=datetime.datetime(2022, 8, 18, 16, 34, 16, 549000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 18, 16, 34, 20, 388000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:986516e8-f0d3-4f2a-a18e-60f9874622bd', digest='99271844', name='QA Notebook by api', description='', created_at=datetime.datetime(2022, 8, 19, 8, 45, 27, 248000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 19, 8, 45, 30, 895000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:4db1ed07-b495-4164-bc9a-cd65e4bebac5', digest='57602073', name='restore:SHISHKIN', description='', created_at=datetime.datetime(2022, 8, 19, 11, 18, 19, 928000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 19, 11, 29, 56, 272000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:003910ad-af66-47d8-a605-effdd3641d30', digest='92469327', name='QA Notebook by api', description='', created_at=datetime.datetime(2022, 8, 22, 8, 4, 1, 746000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 22, 8, 4, 4, 664000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:18785d9c-26f8-4914-84d6-938cc3cea7ce', digest='24200080', name='QA Notebook by SDK', description='description', created_at=datetime.datetime(2022, 8, 22, 8, 4, 7, 250000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 22, 8, 4, 13, 958000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:a39a196c-9c42-49e4-b496-dd99c3deaca7', digest='61166169', name='QA Notebook by api', description='', created_at=datetime.datetime(2022, 8, 22, 8, 4, 15, 654000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 22, 8, 4, 18, 11000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:6af3090b-6b2a-46f8-b0ca-ab4b8410ff77', digest='50374223', name='Test update by SDK', description='Changed by SDK', created_at=datetime.datetime(2022, 8, 22, 8, 4, 56, 39000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 22, 8, 5, 2, 650000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:d9b1f069-4f17-4ecb-8864-b5425e67476b', digest='85425399', name='QA Notebook by api', description='', created_at=datetime.datetime(2022, 8, 22, 8, 5, 4, 237000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 22, 8, 5, 8, 397000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:23b2c86d-025d-495b-bfb0-291da8882be4', digest='32016763', name='QA Notebook by api', description='', created_at=datetime.datetime(2022, 8, 22, 8, 6, 28, 612000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 22, 8, 6, 33, 147000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:9141364b-788e-4537-9ed0-2ba2d143aeea', digest='22358574', name='QA Notebook by api', description='', created_at=datetime.datetime(2022, 8, 22, 16, 8, 14, 484000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 22, 16, 8, 16, 551000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:7ba76178-5630-4558-967c-96bcef441de9', digest='89262066', name='QA Notebook by SDK', description='description', created_at=datetime.datetime(2022, 8, 22, 16, 8, 18, 81000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 22, 16, 8, 19, 634000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:31d50497-c637-41b4-a893-f8b0e1c89957', digest='96568483', name='QA Notebook by api', description='', created_at=datetime.datetime(2022, 8, 22, 16, 8, 21, 66000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 22, 16, 8, 22, 861000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:0d4fac9e-b578-4f9a-8027-9d62c908e657', digest='78500229', name='Test update by SDK', description='Changed by SDK', created_at=datetime.datetime(2022, 8, 22, 16, 8, 35, 703000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 22, 16, 8, 38, 619000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:131ea44d-8aec-4809-bce3-9aad02e491b6', digest='57280389', name='QA Notebook by api', description='', created_at=datetime.datetime(2022, 8, 22, 16, 8, 39, 864000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 22, 16, 8, 41, 809000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:63555307-10b7-474f-a995-77aab76dc5a6', digest='13021419', name='QA Notebook by api', description='', created_at=datetime.datetime(2022, 8, 24, 13, 33, 44, 218000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 24, 13, 33, 49, 30000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:c54da414-87d0-448f-8987-b3f58d819f1e', digest='32169980', name='FOR EXAMPLES SDK', description='DONT DELETE. NO ACTIONS IN UI!', created_at=datetime.datetime(2022, 8, 30, 8, 34, 42, 753000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 30, 8, 34, 42, 753000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:1a6054df-929f-404d-9025-2c59c877ab4f', digest='72609475', name='Test save by SDK', description='Changed by me', created_at=datetime.datetime(2022, 8, 30, 8, 51, 20, 513000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 30, 8, 51, 22, 741000, tzinfo=datetime.timezone.utc)),
#  Notebook(type=<EntityType.NOTEBOOK: 'journal'>, eid='journal:9130927f-48bf-4935-acc2-bb7a23d4b0e6', digest='41102256', name='Test save by SDK', description='Changed by me', created_at=datetime.datetime(2022, 8, 30, 8, 52, 0, 485000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 8, 30, 8, 52, 2, 767000, tzinfo=datetime.timezone.utc))]

# %%
for _property in notebook:
    print(_property)
# Out:
# id='14052' type=None name='My Notebook Field 1 (SK)' description=None value='' values=[]
# id='14051' type=None name='My Notebook Field 2 (SK)' description=None value='' values=[]

# %%
# You can get Property by 2 ways:
# 1. By index of position:
print(notebook[0])

# 2. By key-word (ID):
print(notebook['14051'])
# Out:
# id='14052' type=None name='My Notebook Field 1 (SK)' description=None value='' values=[]
# id='14051' type=None name='My Notebook Field 2 (SK)' description=None value='' values=[]

# %%
notebook[1].set_value('NEW VALUE')
notebook[1]
# Out:
# Property(id='14051', type=None, name='My Notebook Field 2 (SK)', description=None, value='NEW VALUE', values=[])

# %%
notebook.save()
