# %%
# %load_ext dotenv
# %dotenv
import os

SN_API_HOST = os.getenv('SN_API_HOST')
SN_API_KEY = os.getenv('SN_API_KEY')

# %%
from signals_notebook.api import SignalsNotebookApi
SignalsNotebookApi.init(SN_API_HOST, SN_API_KEY)

# %%
from signals_notebook.entities.entity_store import EntityStore
from signals_notebook.common_types import EntityType

# %%
EntityStore.get('experiment:f7fb12b2-1180-4fa0-9bcd-ccc2f7ec0e8f')
# Out:
# Experiment(type=<EntityType.EXPERIMENT: 'experiment'>, eid='experiment:f7fb12b2-1180-4fa0-9bcd-ccc2f7ec0e8f', digest='32454477', name='Test experiment creation by SDK', description='Created by Eugene Pokidov', created_at=datetime.datetime(2022, 2, 3, 14, 42, 52, 42000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 4, 1, 9, 24, 5, 67000, tzinfo=datetime.timezone.utc), state=<ExperimentState.OPEN: 'open'>)

# %%
list(EntityStore.get_list(include_types=[EntityType.BIO_SEQUENCE, EntityType.EXPERIMENT]))
# Out:
# [Experiment(type=<EntityType.EXPERIMENT: 'experiment'>, eid='experiment:4c70c754-19ee-4296-a94d-449379364c41', digest='89163596', name='AAA Test', description='', created_at=datetime.datetime(2022, 3, 21, 15, 46, 30, 51000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 3, 22, 13, 15, 30, 544000, tzinfo=datetime.timezone.utc), state=<ExperimentState.OPEN: 'open'>),
#  Experiment(type=<EntityType.EXPERIMENT: 'experiment'>, eid='experiment:03b041d1-f31d-4b0a-bf9b-fc32a764de74', digest='93518774', name='AK-0001 Request template', description='To analytical lab', created_at=datetime.datetime(2021, 11, 12, 11, 49, 18, 759000, tzinfo=datetime.timezone.utc), edited_at=datetime.datetime(2022, 3, 22, 21, 54, 5, 556000, tzinfo=datetime.timezone.utc), state=None),
# ...
